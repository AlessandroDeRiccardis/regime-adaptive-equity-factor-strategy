# %% [markdown]
# # 03 IC Analysis
# Estimate burn-in ICs and inspect frozen weights.

# %%
from equity_factor_research.research.ic_analysis import estimate_frozen_ic_weights, monthly_information_coefficients
